# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %inline matplotlib

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
plt.figure(figsize=(6,6))
df['sibsp'].value_counts().plot(kind='bar')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,7))
df['pclass'].value_counts().plot(kind='pie')
plt.legend()
plt.show()

# %%
df.pclass.describe()
# Out:
# count    891.000000
# mean       2.308642
# std        0.836071
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.000000
# max        3.000000
# Name: pclass, dtype: float64

# %%
#Univariate

# %%
sns.stripplot(y='sibsp',data=df,jitter=True)
plt.show()

# %%
sns.stripplot(y='sibsp',data=df,jitter=False)
plt.show()

# %%
sns.stripplot(y='pclass',data=df)
plt.show()

# %%
# Bivariate

# %%
plt.figure(figsize=(6,6))
sns.stripplot(x='pclass',y='fare',data=df)
plt.ylabel('fare')
plt.show()

# %%
sns.boxplot(x='pclass',y='fare',data=df)
plt.xlabel('pclass',size=15)
plt.ylabel('fare',size=15)
plt.show()

# %%
sns.stripplot(x='sex',y='fare',data=df)
plt.xlabel('sex',size=15)
plt.ylabel('fare',size=15)
plt.show()

# %%
sns.stripplot(x='sex',y='fare',data=df)
plt.xlabel('pclass',size=15)
plt.ylabel('fare',size=15)
plt.show()

# %%
sns.stripplot(x="pclass",y="fare",hue="sex",data=df)
plt.xlabel("pclass",size=15)
plt.ylabel("fare",size=15)
plt.show()
